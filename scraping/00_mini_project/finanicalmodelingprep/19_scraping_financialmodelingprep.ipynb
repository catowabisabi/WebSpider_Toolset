# %% [markdown]
# Import request and Pandas

# %%
import pandas as pd
import requests

# %% [markdown]
# Set api key

# %%
# getting key
#key = pd.read_csv('key.txt', header = None)[0][0]
key = '44437ff083a4c0ff615e4819c9628983'

# %% [markdown]
# Set Ticker / Tickers

# %%
ticker = ['AAPL']

# %%
#https://financialmodelingprep.com/api/v3/income-statement/AAPL?limit=120&apikey=44437ff083a4c0ff615e4819c9628983

URL = 'https://financialmodelingprep.com/api/v3/'
IS = 'income-statement/'
ticker = ticker[0]
period ='annual' #'quarter
limit = 20
r = requests.get('{}{}{}?period={}&limit={}&apikey={}'.format(URL, IS, ticker, period, limit, key))

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# format income statement data to json format

# %%
incomeStatement = r.json()

# %%
type(r.json())
type(r.json()[0])
# Out:
# dict

# %% [markdown]
# turn data to a table

# %%
data = pd.DataFrame.from_dict(r.json()).transpose()

# %%
data.columns = data.iloc[0]
data = data.iloc[1:]

# %%
data
# Out:
# date                                                                            2021-10-31  \
# symbol                                                                                   A
# reportedCurrency                                                                       USD
# cik                                                                             0001090872
# fillingDate                                                                     2021-12-17
# acceptedDate                                                           2021-12-17 17:01:49
# calendarYear                                                                          2021
# period                                                                                  FY
# revenue                                                                         6319000000
# costOfRevenue                                                                   2912000000
# ...

# %%
# Out:
#           Revenue    Earnings
# Year
# 2018  17049000000  2651000000
# 2019  17911000000  3008000000
# 2020  22284000000  3646000000
# 2021  29453000000  6433000000

# %%
# Out:
#         Max Age   End Date   Growth  Earnings Estimate Avg  \
# Period
# 0Q            1 2022-06-30 -0.04100                   2.36
# +1Q           1 2022-09-30 -0.01700                   2.35
# 0Y            1 2022-12-31  0.02800                  10.33
# +1Y           1 2023-12-31  0.05800                  10.93
# +5Y           1        NaT  0.11050                    NaN
# -5Y           1        NaT  0.02935                    NaN
#
#         Earnings Estimate Low  Earnings Estimate High  \
# Period
# 0Q                       2.29                    2.60
# +1Q                      2.25                    2.61
# 0Y                      10.19                   10.94
# +1Y                     10.48                   11.50
# +5Y                       NaN                     NaN
# -5Y                       NaN                     NaN
#
#         Earnings Estimate Year Ago Eps  Earnings Estimate Number Of Analysts  \
# Period
# ...

# %%
# Out:
#                                            2021-12-31     2020-12-31  \
# Research Development                     1742000000.0   1348000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        7598000000.0   4495000000.0
# Minority Interest                          10000000.0     11000000.0
# Net Income                               6433000000.0   3646000000.0
# Selling General Administrative           8146000000.0   6858000000.0
# Gross Profit                            18056000000.0  13043000000.0
# Ebit                                     8168000000.0   4837000000.0
# Operating Income                         8168000000.0   4837000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -238000000.0   -275000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
# Out:
#                                              2021-12-31    2020-12-31  \
# Research Development                       1742000000.0  1348000000.0
# Effect Of Accounting Charges                       None          None
# Income Before Tax                          7598000000.0  4495000000.0
# Minority Interest                            10000000.0    11000000.0
# Net Income                                 6433000000.0  3646000000.0
# ...                                                 ...           ...
# Change To Inventory                        -502000000.0  -123000000.0
# Change To Account Receivables              -611000000.0  -264000000.0
# Other Cashflows From Financing Activities  -112000000.0   -29000000.0
# Change To Netincome                         415000000.0   208000000.0
# Capital Expenditures                      -1294000000.0  -791000000.0
#
#                                              2019-12-31    2018-12-31
# ...

# %%
# Out:
#            Research Development Effect Of Accounting Charges  \
#
# 2021-12-31         1742000000.0                         None
# 2020-12-31         1348000000.0                         None
# 2019-12-31         1126000000.0                         None
# 2018-12-31         1059000000.0                         None
#
#            Income Before Tax Minority Interest    Net Income  \
#
# 2021-12-31      7598000000.0        10000000.0  6433000000.0
# 2020-12-31      4495000000.0        11000000.0  3646000000.0
# 2019-12-31      3305000000.0        11000000.0  3008000000.0
# 2018-12-31      2962000000.0        12300000.0  2651000000.0
#
#            Selling General Administrative   Gross Profit          Ebit  \
#
# 2021-12-31                   8146000000.0  18056000000.0  8168000000.0
# 2020-12-31                   6858000000.0  13043000000.0  4837000000.0
# 2019-12-31                   5577000000.0   9984000000.0  3281000000.0
# ...

# %% [markdown]
# download fundamental data for multiple tickers

# %%
# Out:
# ['fb', 'amzn', 'nflx', 'goog']

# %%
# Out:
# [yfinance.Ticker object <FB>,
#  yfinance.Ticker object <AMZN>,
#  yfinance.Ticker object <NFLX>,
#  yfinance.Ticker object <GOOG>]

# %%
# Out:
#         Data Research Development Effect Of Accounting Charges  \
# 0 2021-12-31         1742000000.0                         None
# 1 2020-12-31         1348000000.0                         None
# 2 2019-12-31         1126000000.0                         None
# 3 2018-12-31         1059000000.0                         None
#
#   Income Before Tax Minority Interest    Net Income  \
# 0      7598000000.0        10000000.0  6433000000.0
# 1      4495000000.0        11000000.0  3646000000.0
# 2      3305000000.0        11000000.0  3008000000.0
# 3      2962000000.0        12300000.0  2651000000.0
#
#   Selling General Administrative   Gross Profit          Ebit  \
# 0                   8146000000.0  18056000000.0  8168000000.0
# 1                   6858000000.0  13043000000.0  4837000000.0
# 2                   5577000000.0   9984000000.0  3281000000.0
# 3                   5356000000.0   9505000000.0  3090000000.0
#
# ...

# %%
# Out:
# C:\Users\enoma\AppData\Local\Temp\ipykernel_10536\2303959853.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only.
#   df = df.set_index('Ticker', 'Data')
#              Data Research Development Effect Of Accounting Charges  \
# Ticker
# FB     2021-12-31         1742000000.0                         None
# FB     2020-12-31         1348000000.0                         None
# FB     2019-12-31         1126000000.0                         None
# FB     2018-12-31         1059000000.0                         None
# AMZN   2021-12-31         1742000000.0                         None
# AMZN   2020-12-31         1348000000.0                         None
# AMZN   2019-12-31         1126000000.0                         None
# AMZN   2018-12-31         1059000000.0                         None
# NFLX   2021-12-31         1742000000.0                         None
# ...

# %% [markdown]
# How to Get Options Data

# %%
# Out:
# yfinance.Ticker object <AAPL>

# %%
# Out:
# Options(calls=          contractSymbol             lastTradeDate   strike  lastPrice  \
# 0    AAPL220617C00028750 2022-06-10 17:49:25+00:00    28.75     109.70
# 1    AAPL220617C00030000 2022-06-15 16:46:01+00:00    30.00     105.60
# 2    AAPL220617C00031250 2022-06-10 13:59:59+00:00    31.25     107.15
# 3    AAPL220617C00032500 2022-06-03 15:10:12+00:00    32.50     112.40
# 4    AAPL220617C00033750 2022-06-07 18:43:00+00:00    33.75     114.75
# ..                   ...                       ...      ...        ...
# 150  AAPL220617C00680000 2020-08-27 16:59:15+00:00   680.00     333.83
# 151  AAPL220617C00700000 2020-08-28 19:12:54+00:00   700.00    1125.00
# 152  AAPL220617C00720000 2020-08-28 16:29:09+00:00   720.00    1106.80
# 153  AAPL220617C00740000 2020-08-28 17:46:32+00:00   740.00     932.00
# 154  AAPL220617C01000000 2020-08-28 19:48:09+00:00  1000.00      20.31
#
#         bid     ask       change  percentChange  volume  openInterest  \
# ...

# %%
# Out:
# ('2022-06-17',
#  '2022-06-24',
#  '2022-07-01',
#  '2022-07-08',
#  '2022-07-15',
#  '2022-07-22',
#  '2022-07-29',
#  '2022-08-19',
#  '2022-09-16',
#  '2022-10-21',
#  '2022-11-18',
#  '2022-12-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16',
#  '2023-09-15',
#  '2024-01-19',
#  '2024-06-21')

# %%
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    AAPL220617P00028750 2022-06-15 14:17:40+00:00   28.75       0.01    0.00
# 1    AAPL220617P00030000 2022-06-13 14:21:52+00:00   30.00       0.01    0.00
# 2    AAPL220617P00031250 2022-02-08 14:30:04+00:00   31.25       0.02    0.00
# 3    AAPL220617P00032500 2022-03-22 15:12:03+00:00   32.50       0.02    0.00
# 4    AAPL220617P00033750 2022-05-12 16:05:32+00:00   33.75       0.01    0.00
# ..                   ...                       ...     ...        ...     ...
# 142  AAPL220617P00600000 2020-08-27 16:53:15+00:00  600.00     170.00  166.65
# 143  AAPL220617P00640000 2020-08-07 14:08:26+00:00  640.00     218.72  196.65
# 144  AAPL220617P00700000 2020-08-24 18:56:07+00:00  700.00      18.60    4.55
# 145  AAPL220617P00720000 2020-08-24 18:56:07+00:00  720.00       5.06    4.90
# 146  AAPL220617P00800000 2020-08-27 13:54:52+00:00  800.00       6.65    6.50
#
# ...

# %% [markdown]
# How to Get Institutional Holders Using yfinance

# %%
# Out:
#                               Holder      Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  1269995750    2022-03-30  0.0785
# 1                     Blackrock Inc.  1027632887    2022-03-30  0.0635
# 2            Berkshire Hathaway, Inc   890923410    2022-03-30  0.0550
# 3           State Street Corporation   613852274    2022-03-30  0.0379
# 4                           FMR, LLC   351584762    2022-03-30  0.0217
# 5      Geode Capital Management, LLC   272081668    2022-03-30  0.0168
# 6      Price (T.Rowe) Associates Inc   233079365    2022-03-30  0.0144
# 7         Northern Trust Corporation   186031985    2022-03-30  0.0115
# 8        Bank of America Corporation   144401747    2022-03-30  0.0089
# 9  Norges Bank Investment Management   142076403    2021-12-30  0.0088
#
#           Value
# 0  221753957907
# 1  179434978399
# 2  155564136620
# 3  107184745563
# 4   61390215292
# 5   47508180049
# 6   40697987922
# 7   32483044900
# 8   25213989043
# ...

# %% [markdown]
# Why You Shouldn't Use Yahoo Finance for Live Trading

# %%
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                                1.213200e+10 -1.452000e+10
# Change To Liabilities                      1.623000e+09  9.100000e+07
# Total Cashflows From Investing Activities -7.570000e+09 -3.005900e+10
# Net Borrowings                            -6.630000e+08 -5.800000e+08
# Total Cash From Financing Activities      -5.072800e+10 -1.029200e+10
# Change To Operating Activities             2.187000e+09 -1.302000e+09
# Net Income                                 3.937000e+10  2.914600e+10
# Change In Cash                            -1.089000e+09 -1.325000e+09
# Repurchase Of Stock                       -5.005200e+10 -9.836000e+09
# Effect Of Exchange Rate                   -4.740000e+08  2.790000e+08
# Total Cash From Operating Activities       5.768300e+10  3.874700e+10
# Depreciation                               7.967000e+09  6.862000e+09
# ...

# %%
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                                1.213200e+10 -1.452000e+10
# Change To Liabilities                      1.623000e+09  9.100000e+07
# Total Cashflows From Investing Activities -7.570000e+09 -3.005900e+10
# Net Borrowings                            -6.630000e+08 -5.800000e+08
# Total Cash From Financing Activities      -5.072800e+10 -1.029200e+10
# Change To Operating Activities             2.187000e+09 -1.302000e+09
# Net Income                                 3.937000e+10  2.914600e+10
# Change In Cash                            -1.089000e+09 -1.325000e+09
# Repurchase Of Stock                       -5.005200e+10 -9.836000e+09
# Effect Of Exchange Rate                   -4.740000e+08  2.790000e+08
# Total Cash From Operating Activities       5.768300e+10  3.874700e+10
# Depreciation                               7.967000e+09  6.862000e+09
# ...
